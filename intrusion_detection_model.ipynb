# %%
import numpy as np 
import pandas as pd

# %%
df_normal = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_Normal.csv")
df_back = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back.csv")
df_buffer = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_BufferOverflow.csv")
df_ftp = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_FTPWrite.csv")
df_guess = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_GuessPassword.csv")
df_neptune = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_Neptune.csv")
df_nmap = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_NMap.csv")
df_portsweep = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_PortSweep.csv")
df_rootkit = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_RootKit.csv")
df_satan = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_Satan.csv")
df_smurf = pd.read_csv(r"D:\AnalytixLabs\Data Science & AI\Case Studies\Machine Learning Case Studies\2. Capstone Case Study - Cyber Security Case Study\Data_of_Attack_Back_Smurf.csv")

# %%
df_normal['attack'] = 'Normal'
df_back['attack'] = 'Back'
df_buffer['attack'] = 'BufferOverflow'
df_ftp['attack'] = 'FTPWrite'
df_guess['attack'] = 'GuessPassword'
df_neptune['attack'] = 'Neptune'
df_nmap['attack'] = 'NMap'
df_portsweep['attack'] = 'PortSweep'
df_rootkit['attack'] = 'RootKit'
df_satan['attack'] = 'Satan'
df_smurf['attack'] = 'Smurf'

# %%
df = pd.concat([
    df_normal, df_back, df_buffer, df_ftp, df_guess,
    df_neptune, df_nmap, df_portsweep, df_rootkit,
    df_satan, df_smurf
], ignore_index=True)

# %%
df.shape
# Out:
# (817550, 83)

# %%
df['attack'].value_counts()
# Out:
# attack
# Normal            576710
# Neptune           227228
# Satan               5019
# Smurf               3007
# PortSweep           2964
# NMap                1554
# Back                 968
# GuessPassword         53
# BufferOverflow        30
# RootKit               10
# FTPWrite               7
# Name: count, dtype: int64
